# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_df = pd.read_csv('./local_data/TB_Burden_Country.csv')

# %%
dataset_df.shape
# Out:
# (5120, 47)

# %%
dataset_df
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 0                  Afghanistan                                     AF
# 1                  Afghanistan                                     AF
# 2                  Afghanistan                                     AF
# 3                  Afghanistan                                     AF
# 4                  Afghanistan                                     AF
# ...                        ...                                    ...
# 5115                  Zimbabwe                                     ZW
# 5116                  Zimbabwe                                     ZW
# 5117                  Zimbabwe                                     ZW
# 5118                  Zimbabwe                                     ZW
# 5119                  Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# 1                                       AFG
# 2                                       AFG
# 3                                       AFG
# 4                                       AFG
# ...                                     ...
# 5115                                    ZWE
# 5116                                    ZWE
# 5117                                    ZWE
# 5118                                    ZWE
# 5119                                    ZWE
#
#       ISO numeric country/territory code Region  Year  \
# 0                                      4    EMR  1990
# 1                                      4    EMR  1991
# 2                                      4    EMR  1992
# 3                                      4    EMR  1993
# 4                                      4    EMR  1994
# ...                                  ...    ...   ...
# 5115                                 716    AFR  2009
# 5116                                 716    AFR  2010
# 5117                                 716    AFR  2011
# 5118                                 716    AFR  2012
# 5119                                 716    AFR  2013
#
#       Estimated total population number  \
# 0                              11731193
# 1                              12612043
# 2                              13811876
# 3                              15175325
# 4                              16485018
# ...                                 ...
# 5115                           12888918
# 5116                           13076978
# 5117                           13358738
# 5118                           13724317
# 5119                           14149648
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                                 306.0
# 1                                                 343.0
# 2                                                 371.0
# 3                                                 392.0
# 4                                                 410.0
# ...                                                 ...
# 5115                                              449.0
# 5116                                              415.0
# 5117                                              417.0
# 5118                                              425.0
# 5119                                              409.0
#
#       Estimated prevalence of TB (all forms) per 100 000 population, low bound  \
# 0                                                 156.0
# 1                                                 178.0
# 2                                                 189.0
# 3                                                 194.0
# 4                                                 198.0
# ...                                                 ...
# 5115                                              258.0
# 5116                                              239.0
# 5117                                              241.0
# 5118                                              245.0
# 5119                                              235.0
#
#       Estimated prevalence of TB (all forms) per 100 000 population, high bound  \
# 0                                                 506.0
# 1                                                 562.0
# 2                                                 614.0
# 3                                                 657.0
# 4                                                 697.0
# ...                                                 ...
# 5115                                              692.0
# 5116                                              639.0
# 5117                                              639.0
# 5118                                              654.0
# 5119                                              630.0
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5115  ...
# 5116  ...
# 5117  ...
# 5118  ...
# 5119  ...
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population  \
# 0                                                  0.11
# 1                                                  0.13
# 2                                                  0.16
# 3                                                  0.19
# 4                                                  0.21
# ...                                                 ...
# 5115                                             511.00
# 5116                                             487.00
# 5117                                             448.00
# 5118                                             411.00
# 5119                                             395.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound  \
# 0                                                  0.08
# 1                                                  0.11
# 2                                                  0.14
# 3                                                  0.17
# 4                                                  0.18
# ...                                                 ...
# 5115                                             460.00
# 5116                                             433.00
# 5117                                             403.00
# 5118                                             362.00
# 5119                                             341.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound  \
# 0                                                  0.14
# 1                                                  0.16
# 2                                                  0.18
# 3                                                  0.21
# 4                                                  0.24
# ...                                                 ...
# 5115                                             566.00
# 5116                                             545.00
# 5117                                             502.00
# 5118                                             471.00
# 5119                                             464.00
#
#      Estimated incidence of TB cases who are HIV-positive  \
# 0                                                  12.0
# 1                                                  17.0
# 2                                                  22.0
# 3                                                  28.0
# 4                                                  35.0
# ...                                                 ...
# 5115                                            66000.0
# 5116                                            64000.0
# 5117                                            60000.0
# 5118                                            56000.0
# 5119                                            56000.0
#
#       Estimated incidence of TB cases who are HIV-positive, low bound  \
# 0                                                   9.4
# 1                                                  14.0
# 2                                                  19.0
# 3                                                  25.0
# 4                                                  30.0
# ...                                                 ...
# 5115                                            59000.0
# 5116                                            57000.0
# 5117                                            54000.0
# 5118                                            50000.0
# 5119                                            48000.0
#
#       Estimated incidence of TB cases who are HIV-positive, high bound  \
# 0                                                  16.0
# 1                                                  20.0
# 2                                                  24.0
# 3                                                  31.0
# 4                                                  39.0
# ...                                                 ...
# 5115                                            73000.0
# 5116                                            71000.0
# 5117                                            67000.0
# 5118                                            65000.0
# 5119                                            66000.0
#
#       Method to derive TBHIV estimates  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 5115                               NaN
# 5116                               NaN
# 5117                               NaN
# 5118                               NaN
# 5119                               NaN
#
#       Case detection rate (all forms), percent  \
# 0                                         20.0
# 1                                         96.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5115                                      50.0
# 5116                                      53.0
# 5117                                      48.0
# 5118                                      45.0
# 5119                                      42.0
#
#       Case detection rate (all forms), percent, low bound  \
# 0                                                  15.0
# 1                                                  80.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               45.0
# 5116                                               48.0
# 5117                                               43.0
# 5118                                               40.0
# 5119                                               36.0
#
#       Case detection rate (all forms), percent, high bound
# 0                                                  24.0
# 1                                                 110.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               54.0
# 5116                                               59.0
# 5117                                               53.0
# 5118                                               52.0
# 5119                                               49.0
#
# [5120 rows x 47 columns]

# %%
dataset_df.columns
# Out:
# Index(['Country or territory name', 'ISO 2-character country/territory code',
#        'ISO 3-character country/territory code',
#        'ISO numeric country/territory code', 'Region', 'Year',
#        'Estimated total population number',
#        'Estimated prevalence of TB (all forms) per 100 000 population',
#        'Estimated prevalence of TB (all forms) per 100 000 population, low bound',
#        'Estimated prevalence of TB (all forms) per 100 000 population, high bound',
#        'Estimated prevalence of TB (all forms)',
#        'Estimated prevalence of TB (all forms), low bound',
#        'Estimated prevalence of TB (all forms), high bound',
#        'Method to derive prevalence estimates',
#        'Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV)',
#        'Estimated number of deaths from TB (all forms, excluding HIV), low bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV), high bound',
#        'Estimated mortality of TB cases who are HIV-positive, per 100 000 population',
#        'Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound',
#        'Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound',
#        'Estimated number of deaths from TB in people who are HIV-positive',
#        'Estimated number of deaths from TB in people who are HIV-positive, low bound',
#        'Estimated number of deaths from TB in people who are HIV-positive, high bound',
#        'Method to derive mortality estimates',
#        'Estimated incidence (all forms) per 100 000 population',
#        'Estimated incidence (all forms) per 100 000 population, low bound',
#        'Estimated incidence (all forms) per 100 000 population, high bound',
#        'Estimated number of incident cases (all forms)',
#        'Estimated number of incident cases (all forms), low bound',
#        'Estimated number of incident cases (all forms), high bound',
#        'Method to derive incidence estimates',
#        'Estimated HIV in incident TB (percent)',
#        'Estimated HIV in incident TB (percent), low bound',
#        'Estimated HIV in incident TB (percent), high bound',
#        'Estimated incidence of TB cases who are HIV-positive per 100 000 population',
#        'Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound',
#        'Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound',
#        'Estimated incidence of TB cases who are HIV-positive',
#        'Estimated incidence of TB cases who are HIV-positive, low bound',
#        'Estimated incidence of TB cases who are HIV-positive, high bound',
#        'Method to derive TBHIV estimates',
#        'Case detection rate (all forms), percent',
#        'Case detection rate (all forms), percent, low bound',
#        'Case detection rate (all forms), percent, high bound'],
#       dtype='object')

# %%
dataset_df.dtypes
# Out:
# Country or territory name                                                                          object
# ISO 2-character country/territory code                                                             object
# ISO 3-character country/territory code                                                             object
# ISO numeric country/territory code                                                                  int64
# Region                                                                                             object
# Year                                                                                                int64
# Estimated total population number                                                                   int64
# Estimated prevalence of TB (all forms) per 100 000 population                                     float64
# Estimated prevalence of TB (all forms) per 100 000 population, low bound                          float64
# Estimated prevalence of TB (all forms) per 100 000 population, high bound                         float64
# Estimated prevalence of TB (all forms)                                                            float64
# Estimated prevalence of TB (all forms), low bound                                                 float64
# Estimated prevalence of TB (all forms), high bound                                                float64
# Method to derive prevalence estimates                                                              object
# Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population                 float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound     float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound    float64
# Estimated number of deaths from TB (all forms, excluding HIV)                                     float64
# Estimated number of deaths from TB (all forms, excluding HIV), low bound                          float64
# Estimated number of deaths from TB (all forms, excluding HIV), high bound                         float64
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population                      float64
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound           float64
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound          float64
# Estimated number of deaths from TB in people who are HIV-positive                                 float64
# Estimated number of deaths from TB in people who are HIV-positive, low bound                      float64
# Estimated number of deaths from TB in people who are HIV-positive, high bound                     float64
# Method to derive mortality estimates                                                               object
# Estimated incidence (all forms) per 100 000 population                                            float64
# Estimated incidence (all forms) per 100 000 population, low bound                                 float64
# Estimated incidence (all forms) per 100 000 population, high bound                                float64
# Estimated number of incident cases (all forms)                                                    float64
# Estimated number of incident cases (all forms), low bound                                         float64
# Estimated number of incident cases (all forms), high bound                                        float64
# Method to derive incidence estimates                                                               object
# Estimated HIV in incident TB (percent)                                                            float64
# Estimated HIV in incident TB (percent), low bound                                                 float64
# Estimated HIV in incident TB (percent), high bound                                                float64
# Estimated incidence of TB cases who are HIV-positive per 100 000 population                       float64
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound            float64
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound           float64
# Estimated incidence of TB cases who are HIV-positive                                              float64
# Estimated incidence of TB cases who are HIV-positive, low bound                                   float64
# Estimated incidence of TB cases who are HIV-positive, high bound                                  float64
# Method to derive TBHIV estimates                                                                  float64
# Case detection rate (all forms), percent                                                          float64
# Case detection rate (all forms), percent, low bound                                               float64
# Case detection rate (all forms), percent, high bound                                              float64
# dtype: object

# %%
int_cols = dataset_df.select_dtypes(include='int64').columns

# %%
int_cols
# Out:
# Index(['ISO numeric country/territory code', 'Year',
#        'Estimated total population number'],
#       dtype='object')

# %%
duplicates = dataset_df.duplicated()
print(duplicates)
dataset_df[dataset_df.duplicated(keep=False)]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5115    False
# 5116    False
# 5117    False
# 5118    False
# 5119    False
# Length: 5120, dtype: bool
# Empty DataFrame
# Columns: [Country or territory name, ISO 2-character country/territory code, ISO 3-character country/territory code, ISO numeric country/territory code, Region, Year, Estimated total population number, Estimated prevalence of TB (all forms) per 100 000 population, Estimated prevalence of TB (all forms) per 100 000 population, low bound, Estimated prevalence of TB (all forms) per 100 000 population, high bound, Estimated prevalence of TB (all forms), Estimated prevalence of TB (all forms), low bound, Estimated prevalence of TB (all forms), high bound, Method to derive prevalence estimates, Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population, Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound, Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound, Estimated number of deaths from TB (all forms, excluding HIV), Estimated number of deaths from TB (all forms, excluding HIV), low bound, Estimated number of deaths from TB (all forms, excluding HIV), high bound, Estimated mortality of TB cases who are HIV-positive, per 100 000 population, Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound, Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound, Estimated number of deaths from TB in people who are HIV-positive, Estimated number of deaths from TB in people who are HIV-positive, low bound, Estimated number of deaths from TB in people who are HIV-positive, high bound, Method to derive mortality estimates, Estimated incidence (all forms) per 100 000 population, Estimated incidence (all forms) per 100 000 population, low bound, Estimated incidence (all forms) per 100 000 population, high bound, Estimated number of incident cases (all forms), Estimated number of incident cases (all forms), low bound, Estimated number of incident cases (all forms), high bound, Method to derive incidence estimates, Estimated HIV in incident TB (percent), Estimated HIV in incident TB (percent), low bound, Estimated HIV in incident TB (percent), high bound, Estimated incidence of TB cases who are HIV-positive per 100 000 population, Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound, Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound, Estimated incidence of TB cases who are HIV-positive, Estimated incidence of TB cases who are HIV-positive, low bound, Estimated incidence of TB cases who are HIV-positive, high bound, Method to derive TBHIV estimates, Case detection rate (all forms), percent, Case detection rate (all forms), percent, low bound, Case detection rate (all forms), percent, high bound]
# Index: []
#
# [0 rows x 47 columns]

# %%
null_value = dataset_df.isnull().sum()
print(null_value)
# Out:
# Country or territory name                                                                            0
# ISO 2-character country/territory code                                                              24
# ISO 3-character country/territory code                                                               0
# ISO numeric country/territory code                                                                   0
# Region                                                                                               0
# Year                                                                                                 0
# Estimated total population number                                                                    0
# Estimated prevalence of TB (all forms) per 100 000 population                                        0
# Estimated prevalence of TB (all forms) per 100 000 population, low bound                            20
# Estimated prevalence of TB (all forms) per 100 000 population, high bound                           20
# Estimated prevalence of TB (all forms)                                                               0
# Estimated prevalence of TB (all forms), low bound                                                   20
# Estimated prevalence of TB (all forms), high bound                                                  20
# Method to derive prevalence estimates                                                                0
# Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population                    0
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound        0
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound       0
# Estimated number of deaths from TB (all forms, excluding HIV)                                        0
# Estimated number of deaths from TB (all forms, excluding HIV), low bound                             0
# Estimated number of deaths from TB (all forms, excluding HIV), high bound                            0
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population                         0
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound           1942
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound          1942
# Estimated number of deaths from TB in people who are HIV-positive                                    0
# Estimated number of deaths from TB in people who are HIV-positive, low bound                      1942
# Estimated number of deaths from TB in people who are HIV-positive, high bound                     1942
# Method to derive mortality estimates                                                                 0
# Estimated incidence (all forms) per 100 000 population                                               0
# Estimated incidence (all forms) per 100 000 population, low bound                                   94
# Estimated incidence (all forms) per 100 000 population, high bound                                  94
# Estimated number of incident cases (all forms)                                                       0
# Estimated number of incident cases (all forms), low bound                                           94
# Estimated number of incident cases (all forms), high bound                                          94
# Method to derive incidence estimates                                                              2133
# Estimated HIV in incident TB (percent)                                                            1475
# Estimated HIV in incident TB (percent), low bound                                                 1478
# Estimated HIV in incident TB (percent), high bound                                                1478
# Estimated incidence of TB cases who are HIV-positive per 100 000 population                       1475
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound            1478
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound           1478
# Estimated incidence of TB cases who are HIV-positive                                              1475
# Estimated incidence of TB cases who are HIV-positive, low bound                                   1478
# Estimated incidence of TB cases who are HIV-positive, high bound                                  1478
# Method to derive TBHIV estimates                                                                  5120
# Case detection rate (all forms), percent                                                           449
# Case detection rate (all forms), percent, low bound                                                449
# Case detection rate (all forms), percent, high bound                                               449
# dtype: int64

# %%
row_with_missing_values = dataset_df[dataset_df.isna().any(axis=1)]
print(row_with_missing_values)
null_vals = dataset_df.isnull().sum()
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 0                  Afghanistan                                     AF
# 1                  Afghanistan                                     AF
# 2                  Afghanistan                                     AF
# 3                  Afghanistan                                     AF
# 4                  Afghanistan                                     AF
# ...                        ...                                    ...
# 5115                  Zimbabwe                                     ZW
# 5116                  Zimbabwe                                     ZW
# 5117                  Zimbabwe                                     ZW
# 5118                  Zimbabwe                                     ZW
# 5119                  Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# 1                                       AFG
# 2                                       AFG
# 3                                       AFG
# 4                                       AFG
# ...                                     ...
# 5115                                    ZWE
# 5116                                    ZWE
# 5117                                    ZWE
# 5118                                    ZWE
# 5119                                    ZWE
#
#       ISO numeric country/territory code Region  Year  \
# 0                                      4    EMR  1990
# 1                                      4    EMR  1991
# 2                                      4    EMR  1992
# 3                                      4    EMR  1993
# 4                                      4    EMR  1994
# ...                                  ...    ...   ...
# 5115                                 716    AFR  2009
# 5116                                 716    AFR  2010
# 5117                                 716    AFR  2011
# 5118                                 716    AFR  2012
# 5119                                 716    AFR  2013
#
#       Estimated total population number  \
# 0                              11731193
# 1                              12612043
# 2                              13811876
# 3                              15175325
# 4                              16485018
# ...                                 ...
# 5115                           12888918
# 5116                           13076978
# 5117                           13358738
# 5118                           13724317
# 5119                           14149648
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                                 306.0
# 1                                                 343.0
# 2                                                 371.0
# 3                                                 392.0
# 4                                                 410.0
# ...                                                 ...
# 5115                                              449.0
# 5116                                              415.0
# 5117                                              417.0
# 5118                                              425.0
# 5119                                              409.0
#
#       Estimated prevalence of TB (all forms) per 100 000 population, low bound  \
# 0                                                 156.0
# 1                                                 178.0
# 2                                                 189.0
# 3                                                 194.0
# 4                                                 198.0
# ...                                                 ...
# 5115                                              258.0
# 5116                                              239.0
# 5117                                              241.0
# 5118                                              245.0
# 5119                                              235.0
#
#       Estimated prevalence of TB (all forms) per 100 000 population, high bound  \
# 0                                                 506.0
# 1                                                 562.0
# 2                                                 614.0
# 3                                                 657.0
# 4                                                 697.0
# ...                                                 ...
# 5115                                              692.0
# 5116                                              639.0
# 5117                                              639.0
# 5118                                              654.0
# 5119                                              630.0
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5115  ...
# 5116  ...
# 5117  ...
# 5118  ...
# 5119  ...
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population  \
# 0                                                  0.11
# 1                                                  0.13
# 2                                                  0.16
# 3                                                  0.19
# 4                                                  0.21
# ...                                                 ...
# 5115                                             511.00
# 5116                                             487.00
# 5117                                             448.00
# 5118                                             411.00
# 5119                                             395.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound  \
# 0                                                  0.08
# 1                                                  0.11
# 2                                                  0.14
# 3                                                  0.17
# 4                                                  0.18
# ...                                                 ...
# 5115                                             460.00
# 5116                                             433.00
# 5117                                             403.00
# 5118                                             362.00
# 5119                                             341.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound  \
# 0                                                  0.14
# 1                                                  0.16
# 2                                                  0.18
# 3                                                  0.21
# 4                                                  0.24
# ...                                                 ...
# 5115                                             566.00
# 5116                                             545.00
# 5117                                             502.00
# 5118                                             471.00
# 5119                                             464.00
#
#      Estimated incidence of TB cases who are HIV-positive  \
# 0                                                  12.0
# 1                                                  17.0
# 2                                                  22.0
# 3                                                  28.0
# 4                                                  35.0
# ...                                                 ...
# 5115                                            66000.0
# 5116                                            64000.0
# 5117                                            60000.0
# 5118                                            56000.0
# 5119                                            56000.0
#
#       Estimated incidence of TB cases who are HIV-positive, low bound  \
# 0                                                   9.4
# 1                                                  14.0
# 2                                                  19.0
# 3                                                  25.0
# 4                                                  30.0
# ...                                                 ...
# 5115                                            59000.0
# 5116                                            57000.0
# 5117                                            54000.0
# 5118                                            50000.0
# 5119                                            48000.0
#
#       Estimated incidence of TB cases who are HIV-positive, high bound  \
# 0                                                  16.0
# 1                                                  20.0
# 2                                                  24.0
# 3                                                  31.0
# 4                                                  39.0
# ...                                                 ...
# 5115                                            73000.0
# 5116                                            71000.0
# 5117                                            67000.0
# 5118                                            65000.0
# 5119                                            66000.0
#
#       Method to derive TBHIV estimates  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 5115                               NaN
# 5116                               NaN
# 5117                               NaN
# 5118                               NaN
# 5119                               NaN
#
#       Case detection rate (all forms), percent  \
# 0                                         20.0
# 1                                         96.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5115                                      50.0
# 5116                                      53.0
# 5117                                      48.0
# 5118                                      45.0
# 5119                                      42.0
#
#       Case detection rate (all forms), percent, low bound  \
# 0                                                  15.0
# 1                                                  80.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               45.0
# 5116                                               48.0
# 5117                                               43.0
# 5118                                               40.0
# 5119                                               36.0
#
#       Case detection rate (all forms), percent, high bound
# 0                                                  24.0
# 1                                                 110.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               54.0
# 5116                                               59.0
# 5117                                               53.0
# 5118                                               52.0
# 5119                                               49.0
#
# [5120 rows x 47 columns]

# %%
dataset_df.drop('Method to derive TBHIV estimates', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive, low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence of TB cases who are HIV-positive per 100 000 population', axis = 1, inplace = True)
dataset_df.drop('Estimated HIV in incident TB (percent), high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated HIV in incident TB (percent), low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated HIV in incident TB (percent)', axis = 1, inplace = True)
dataset_df.drop('Method to derive incidence estimates', axis = 1, inplace = True)
dataset_df.drop('Estimated number of deaths from TB in people who are HIV-positive, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated number of deaths from TB in people who are HIV-positive, low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound', axis = 1, inplace = True)
dataset_df.drop('ISO 2-character country/territory code', axis = 1, inplace = True)
dataset_df.drop('Estimated prevalence of TB (all forms) per 100 000 population, low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated prevalence of TB (all forms) per 100 000 population, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated prevalence of TB (all forms), low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated prevalence of TB (all forms), high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence (all forms) per 100 000 population, low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated incidence (all forms) per 100 000 population, high bound', axis = 1, inplace = True)
dataset_df.drop('Estimated number of incident cases (all forms), low bound', axis = 1, inplace = True)
dataset_df.drop('Estimated number of incident cases (all forms), high bound', axis = 1, inplace = True)
dataset_df.drop('Case detection rate (all forms), percent', axis = 1, inplace = True)
dataset_df.drop('Case detection rate (all forms), percent, low bound', axis = 1, inplace = True)
dataset_df.drop('Case detection rate (all forms), percent, high bound', axis = 1, inplace = True)

# %%
dataset_df.dtypes
# Out:
# Country or territory name                                                                          object
# ISO 3-character country/territory code                                                             object
# ISO numeric country/territory code                                                                  int64
# Region                                                                                             object
# Year                                                                                                int64
# Estimated total population number                                                                   int64
# Estimated prevalence of TB (all forms) per 100 000 population                                     float64
# Estimated prevalence of TB (all forms)                                                            float64
# Method to derive prevalence estimates                                                              object
# Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population                 float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound     float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound    float64
# Estimated number of deaths from TB (all forms, excluding HIV)                                     float64
# Estimated number of deaths from TB (all forms, excluding HIV), low bound                          float64
# Estimated number of deaths from TB (all forms, excluding HIV), high bound                         float64
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population                      float64
# Estimated number of deaths from TB in people who are HIV-positive                                 float64
# Method to derive mortality estimates                                                               object
# Estimated incidence (all forms) per 100 000 population                                            float64
# Estimated number of incident cases (all forms)                                                    float64
# dtype: object

# %%
null_value = dataset_df.isnull().sum()
print(null_value)
# Out:
# Country or territory name                                                                         0
# ISO 3-character country/territory code                                                            0
# ISO numeric country/territory code                                                                0
# Region                                                                                            0
# Year                                                                                              0
# Estimated total population number                                                                 0
# Estimated prevalence of TB (all forms) per 100 000 population                                     0
# Estimated prevalence of TB (all forms)                                                            0
# Method to derive prevalence estimates                                                             0
# Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population                 0
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound     0
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound    0
# Estimated number of deaths from TB (all forms, excluding HIV)                                     0
# Estimated number of deaths from TB (all forms, excluding HIV), low bound                          0
# Estimated number of deaths from TB (all forms, excluding HIV), high bound                         0
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population                      0
# Estimated number of deaths from TB in people who are HIV-positive                                 0
# Method to derive mortality estimates                                                              0
# Estimated incidence (all forms) per 100 000 population                                            0
# Estimated number of incident cases (all forms)                                                    0
# dtype: int64

# %%
print(all(np.where(dataset_df['Year']>0, True, False)))
print(all(np.where(dataset_df['ISO numeric country/territory code']>0, True, False)))
print(all(np.where(dataset_df['Estimated total population number']>0, True, False)))
# Out:
# True
# True
# True

# %%
df_floats = dataset_df.select_dtypes(include='float64').columns
print(df_floats)
# Out:
# Index(['Estimated prevalence of TB (all forms) per 100 000 population',
#        'Estimated prevalence of TB (all forms)',
#        'Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV)',
#        'Estimated number of deaths from TB (all forms, excluding HIV), low bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV), high bound',
#        'Estimated mortality of TB cases who are HIV-positive, per 100 000 population',
#        'Estimated number of deaths from TB in people who are HIV-positive',
#        'Estimated incidence (all forms) per 100 000 population',
#        'Estimated number of incident cases (all forms)'],
#       dtype='object')

# %%
def check_all_floats(df: object, column_name: str):
    ''' Checks if all values in a column are floats '''
    value = df[column_name].apply(lambda x: isinstance(x, float)).all()
    return value
print(check_all_floats(dataset_df, 'Estimated prevalence of TB (all forms) per 100 000 population'))

print(check_all_floats(dataset_df, 'Estimated prevalence of TB (all forms)'))
print(check_all_floats(dataset_df, 'Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population'))
print(check_all_floats(dataset_df, 'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound'))
print(check_all_floats(dataset_df, 'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound'))
print(check_all_floats(dataset_df, 'Estimated number of deaths from TB (all forms, excluding HIV)'))
print(check_all_floats(dataset_df, 'Estimated number of deaths from TB (all forms, excluding HIV), low bound'))
print(check_all_floats(dataset_df, 'Estimated number of deaths from TB (all forms, excluding HIV), high bound'))
print(check_all_floats(dataset_df, 'Estimated mortality of TB cases who are HIV-positive, per 100 000 population'))
print(check_all_floats(dataset_df, 'Estimated number of deaths from TB in people who are HIV-positive'))
print(check_all_floats(dataset_df, 'Estimated incidence (all forms) per 100 000 population'))
print(check_all_floats(dataset_df, 'Estimated number of incident cases (all forms)'))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
df_strings = dataset_df.select_dtypes(include='object').columns
print(df_strings)
# Out:
# Index(['Country or territory name', 'ISO 3-character country/territory code',
#        'Region', 'Method to derive prevalence estimates',
#        'Method to derive mortality estimates'],
#       dtype='object')

# %%
def isStringColumn(df: object, column_name: str):
    is_string_column = df[column_name].apply(lambda x: isinstance(x, str)).all()
    return is_string_column
print(isStringColumn(dataset_df, 'Country or territory name'))
print(isStringColumn(dataset_df, 'ISO 3-character country/territory code'))
print(isStringColumn(dataset_df, 'Region'))
print(isStringColumn(dataset_df, 'Method to derive prevalence estimates'))
print(isStringColumn(dataset_df, 'Method to derive mortality estimates'))
# Out:
# True
# True
# True
# True
# True

# %%
dataset_df.dtypes
# Out:
# Country or territory name                                                                          object
# ISO 3-character country/territory code                                                             object
# ISO numeric country/territory code                                                                  int64
# Region                                                                                             object
# Year                                                                                                int64
# Estimated total population number                                                                   int64
# Estimated prevalence of TB (all forms) per 100 000 population                                     float64
# Estimated prevalence of TB (all forms)                                                            float64
# Method to derive prevalence estimates                                                              object
# Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population                 float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound     float64
# Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound    float64
# Estimated number of deaths from TB (all forms, excluding HIV)                                     float64
# Estimated number of deaths from TB (all forms, excluding HIV), low bound                          float64
# Estimated number of deaths from TB (all forms, excluding HIV), high bound                         float64
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population                      float64
# Estimated number of deaths from TB in people who are HIV-positive                                 float64
# Method to derive mortality estimates                                                               object
# Estimated incidence (all forms) per 100 000 population                                            float64
# Estimated number of incident cases (all forms)                                                    float64
# dtype: object

# %%
def outliersZscore (df: object, column_name: str) :
    z_score = np.abs((df[column_name] - df[column_name].mean() / df[column_name].std()))
    outliers = df[z_score<2]
    return outliers
print(outliersZscore(dataset_df, 'Estimated prevalence of TB (all forms)'))
# Out:
#       Country or territory name ISO 3-character country/territory code  \
# 168         Antigua and Barbuda                                    ATG
# 169         Antigua and Barbuda                                    ATG
# 534                     Bermuda                                    BMU
# 536                     Bermuda                                    BMU
# 537                     Bermuda                                    BMU
# ...                         ...                                    ...
# 4664   Turks and Caicos Islands                                    TCA
# 4665   Turks and Caicos Islands                                    TCA
# 4666   Turks and Caicos Islands                                    TCA
# 5022  Wallis and Futuna Islands                                    WLF
# 5023  Wallis and Futuna Islands                                    WLF
#
#       ISO numeric country/territory code Region  Year  \
# 168                                   28    AMR  1990
# 169                                   28    AMR  1991
# 534                                   60    AMR  1996
# 536                                   60    AMR  1998
# 537                                   60    AMR  1999
# ...                                  ...    ...   ...
# 4664                                 796    AMR  1990
# 4665                                 796    AMR  1991
# 4666                                 796    AMR  1992
# 5022                                 876    WPR  2012
# 5023                                 876    WPR  2013
#
#       Estimated total population number  \
# 168                               61906
# 169                               62412
# 534                               61703
# 536                               62276
# 537                               62557
# ...                                 ...
# 4664                              11550
# 4665                              12205
# 4666                              12970
# 5022                              13353
# 5023                              13272
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 168                                                 2.9
# 169                                                 3.5
# 534                                                 3.3
# 536                                                 1.5
# 537                                                 1.4
# ...                                                 ...
# 4664                                                0.0
# 4665                                                0.0
# 4666                                               11.0
# 5022                                               14.0
# 5023                                               17.0
#
#       Estimated prevalence of TB (all forms)  \
# 168                                     1.80
# 169                                     2.20
# 534                                     2.00
# 536                                     0.95
# 537                                     0.87
# ...                                      ...
# 4664                                    0.00
# 4665                                    0.00
# 4666                                    1.40
# 5022                                    1.80
# 5023                                    2.20
#
#      Method to derive prevalence estimates  \
# 168                              predicted
# 169                              predicted
# 534                              predicted
# 536                              predicted
# 537                              predicted
# ...                                    ...
# 4664                             predicted
# 4665                             predicted
# 4666                             predicted
# 5022                             predicted
# 5023                             predicted
#
#       Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# 168                                                3.90
# 169                                                0.00
# 534                                                0.00
# 536                                                0.00
# 537                                                0.00
# ...                                                 ...
# 4664                                               0.00
# 4665                                               0.00
# 4666                                               0.00
# 5022                                               0.56
# 5023                                               2.30
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound  \
# 168                                                3.50
# 169                                                0.00
# 534                                                0.00
# 536                                                0.00
# 537                                                0.00
# ...                                                 ...
# 4664                                               0.00
# 4665                                               0.00
# 4666                                               0.00
# 5022                                               0.17
# 5023                                               1.50
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound  \
# 168                                                 4.3
# 169                                                 0.0
# 534                                                 0.0
# 536                                                 0.0
# 537                                                 0.0
# ...                                                 ...
# 4664                                                0.0
# 4665                                                0.0
# 4666                                                0.0
# 5022                                                1.2
# 5023                                                3.1
#
#       Estimated number of deaths from TB (all forms, excluding HIV)  \
# 168                                                2.40
# 169                                                0.00
# 534                                                0.00
# 536                                                0.00
# 537                                                0.00
# ...                                                 ...
# 4664                                               0.00
# 4665                                               0.00
# 4666                                               0.00
# 5022                                               0.07
# 5023                                               0.30
#
#       Estimated number of deaths from TB (all forms, excluding HIV), low bound  \
# 168                                                2.20
# 169                                                0.00
# 534                                                0.00
# 536                                                0.00
# 537                                                0.00
# ...                                                 ...
# 4664                                               0.00
# 4665                                               0.00
# 4666                                               0.00
# 5022                                               0.02
# 5023                                               0.21
#
#       Estimated number of deaths from TB (all forms, excluding HIV), high bound  \
# 168                                                2.70
# 169                                                0.00
# 534                                                0.00
# 536                                                0.00
# 537                                                0.00
# ...                                                 ...
# 4664                                               0.00
# 4665                                               0.00
# 4666                                               0.00
# 5022                                               0.16
# 5023                                               0.41
#
#       Estimated mortality of TB cases who are HIV-positive, per 100 000 population  \
# 168                                                 0.0
# 169                                                 0.0
# 534                                                 0.0
# 536                                                 0.0
# 537                                                 0.0
# ...                                                 ...
# 4664                                                0.0
# 4665                                                0.0
# 4666                                                0.0
# 5022                                                0.0
# 5023                                                0.0
#
#       Estimated number of deaths from TB in people who are HIV-positive  \
# 168                                                 0.0
# 169                                                 0.0
# 534                                                 0.0
# 536                                                 0.0
# 537                                                 0.0
# ...                                                 ...
# 4664                                                0.0
# 4665                                                0.0
# 4666                                                0.0
# 5022                                                0.0
# 5023                                                0.0
#
#      Method to derive mortality estimates  \
# 168                                    VR
# 169                                    VR
# 534                                    VR
# 536                                    VR
# 537                                    VR
# ...                                   ...
# 4664                                   VR
# 4665                                   VR
# 4666                                   VR
# 5022                             Indirect
# 5023                             Indirect
#
#       Estimated incidence (all forms) per 100 000 population  \
# 168                                                 1.9
# 169                                                 0.0
# 534                                                 0.0
# 536                                                 0.0
# 537                                                 0.0
# ...                                                 ...
# 4664                                                0.0
# 4665                                                0.0
# 4666                                                0.0
# 5022                                               12.0
# 5023                                                8.7
#
#       Estimated number of incident cases (all forms)
# 168                                              1.1
# 169                                              0.0
# 534                                              0.0
# 536                                              0.0
# 537                                              0.0
# ...                                              ...
# 4664                                             0.0
# 4665                                             0.0
# 4666                                             0.0
# 5022                                             1.6
# 5023                                             1.2
#
# [166 rows x 20 columns]

# %%
plt.hist(dataset_df['Estimated prevalence of TB (all forms)'], bins=5)
# Out:
# (array([5.064e+03, 1.700e+01, 1.600e+01, 5.000e+00, 1.800e+01]),
#  array([      0.,  920000., 1840000., 2760000., 3680000., 4600000.]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(x=dataset_df['Estimated prevalence of TB (all forms)'])
# Out:
# <Axes: xlabel='Estimated prevalence of TB (all forms)'>

# %%
def exclude_outliers_zscore(data:object, column:str) -> 'str':
    z_score = np.abs((data[column] - data[column].mean() / data[column].std()))
    df_excl_outliers = data[(z_score>=2)]
    return df_excl_outliers
print(exclude_outliers_zscore(dataset_df, 'Estimated prevalence of TB (all forms)'))
df_excl_outliers = exclude_outliers_zscore(dataset_df, 'Estimated prevalence of TB (all forms)')
hiv_df_excl_outliers = exclude_outliers_zscore(dataset_df, 'Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population')
dataset_df = df_excl_outliers
dataset_df = hiv_df_excl_outliers
# Out:
#      Country or territory name ISO 3-character country/territory code  \
# 0                  Afghanistan                                    AFG
# 1                  Afghanistan                                    AFG
# 2                  Afghanistan                                    AFG
# 3                  Afghanistan                                    AFG
# 4                  Afghanistan                                    AFG
# ...                        ...                                    ...
# 5115                  Zimbabwe                                    ZWE
# 5116                  Zimbabwe                                    ZWE
# 5117                  Zimbabwe                                    ZWE
# 5118                  Zimbabwe                                    ZWE
# 5119                  Zimbabwe                                    ZWE
#
#       ISO numeric country/territory code Region  Year  \
# 0                                      4    EMR  1990
# 1                                      4    EMR  1991
# 2                                      4    EMR  1992
# 3                                      4    EMR  1993
# 4                                      4    EMR  1994
# ...                                  ...    ...   ...
# 5115                                 716    AFR  2009
# 5116                                 716    AFR  2010
# 5117                                 716    AFR  2011
# 5118                                 716    AFR  2012
# 5119                                 716    AFR  2013
#
#       Estimated total population number  \
# 0                              11731193
# 1                              12612043
# 2                              13811876
# 3                              15175325
# 4                              16485018
# ...                                 ...
# 5115                           12888918
# 5116                           13076978
# 5117                           13358738
# 5118                           13724317
# 5119                           14149648
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                                 306.0
# 1                                                 343.0
# 2                                                 371.0
# 3                                                 392.0
# 4                                                 410.0
# ...                                                 ...
# 5115                                              449.0
# 5116                                              415.0
# 5117                                              417.0
# 5118                                              425.0
# 5119                                              409.0
#
#       Estimated prevalence of TB (all forms)  \
# 0                                    36000.0
# 1                                    43000.0
# 2                                    51000.0
# 3                                    59000.0
# 4                                    68000.0
# ...                                      ...
# 5115                                 58000.0
# 5116                                 54000.0
# 5117                                 56000.0
# 5118                                 58000.0
# 5119                                 58000.0
#
#      Method to derive prevalence estimates  \
# 0                                predicted
# 1                                predicted
# 2                                predicted
# 3                                predicted
# 4                                predicted
# ...                                    ...
# 5115                             predicted
# 5116                             predicted
# 5117                             predicted
# 5118                             predicted
# 5119                             predicted
#
#       Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# 0                                                  37.0
# 1                                                  46.0
# 2                                                  54.0
# 3                                                  60.0
# 4                                                  65.0
# ...                                                 ...
# 5115                                               39.0
# 5116                                               36.0
# 5117                                               38.0
# 5118                                               41.0
# 5119                                               40.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound  \
# 0                                                  24.0
# 1                                                  29.0
# 2                                                  34.0
# 3                                                  38.0
# 4                                                  41.0
# ...                                                 ...
# 5115                                               27.0
# 5116                                               25.0
# 5117                                               26.0
# 5118                                               27.0
# 5119                                               25.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound  \
# 0                                                  54.0
# 1                                                  61.0
# 2                                                  68.0
# 3                                                  73.0
# 4                                                  79.0
# ...                                                 ...
# 5115                                               52.0
# 5116                                               48.0
# 5117                                               51.0
# 5118                                               55.0
# 5119                                               52.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV)  \
# 0                                                4300.0
# 1                                                5800.0
# 2                                                7400.0
# 3                                                9100.0
# 4                                               11000.0
# ...                                                 ...
# 5115                                             5000.0
# 5116                                             4700.0
# 5117                                             5100.0
# 5118                                             5600.0
# 5119                                             5700.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV), low bound  \
# 0                                                2800.0
# 1                                                3700.0
# 2                                                4700.0
# 3                                                5800.0
# 4                                                6800.0
# ...                                                 ...
# 5115                                             3500.0
# 5116                                             3300.0
# 5117                                             3500.0
# 5118                                             3700.0
# 5119                                             3600.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV), high bound  \
# 0                                                6400.0
# 1                                                7700.0
# 2                                                9400.0
# 3                                               11000.0
# 4                                               13000.0
# ...                                                 ...
# 5115                                             6700.0
# 5116                                             6300.0
# 5117                                             6800.0
# 5118                                             7500.0
# 5119                                             7400.0
#
#       Estimated mortality of TB cases who are HIV-positive, per 100 000 population  \
# 0                                                  0.04
# 1                                                  0.06
# 2                                                  0.08
# 3                                                  0.11
# 4                                                  0.13
# ...                                                 ...
# 5115                                             206.00
# 5116                                             196.00
# 5117                                             176.00
# 5118                                             160.00
# 5119                                             153.00
#
#       Estimated number of deaths from TB in people who are HIV-positive  \
# 0                                                   5.0
# 1                                                   8.0
# 2                                                  11.0
# 3                                                  17.0
# 4                                                  22.0
# ...                                                 ...
# 5115                                            27000.0
# 5116                                            26000.0
# 5117                                            24000.0
# 5118                                            22000.0
# 5119                                            22000.0
#
#      Method to derive mortality estimates  \
# 0                                Indirect
# 1                                Indirect
# 2                                Indirect
# 3                                Indirect
# 4                                Indirect
# ...                                   ...
# 5115                             Indirect
# 5116                             Indirect
# 5117                             Indirect
# 5118                             Indirect
# 5119                             Indirect
#
#       Estimated incidence (all forms) per 100 000 population  \
# 0                                                 189.0
# 1                                                 191.0
# 2                                                 191.0
# 3                                                 189.0
# 4                                                 188.0
# ...                                                 ...
# 5115                                              673.0
# 5116                                              635.0
# 5117                                              602.0
# 5118                                              575.0
# 5119                                              552.0
#
#       Estimated number of incident cases (all forms)
# 0                                            22000.0
# 1                                            24000.0
# 2                                            26000.0
# 3                                            29000.0
# 4                                            31000.0
# ...                                              ...
# 5115                                         87000.0
# 5116                                         83000.0
# 5117                                         80000.0
# 5118                                         79000.0
# 5119                                         78000.0
#
# [4954 rows x 20 columns]

# %%
sns.boxplot(x=df_excl_outliers['Estimated prevalence of TB (all forms)'])
# Out:
# <Axes: xlabel='Estimated prevalence of TB (all forms)'>

# %%
plt.hist(df_excl_outliers['Estimated prevalence of TB (all forms)'], bins=5)
# Out:
# (array([4900.,   15.,   16.,    5.,   18.]),
#  array([2.30000000e+00, 9.20001840e+05, 1.84000138e+06, 2.76000092e+06,
#         3.68000046e+06, 4.60000000e+06]),
#  <BarContainer object of 5 artists>)

# %%
df_excl_outliers.describe(include='all')
# Out:
#        Country or territory name ISO 3-character country/territory code  \
# count                       4954                                   4954
# unique                       218                                    218
# top                  Afghanistan                                    AFG
# freq                          24                                     24
# mean                         NaN                                    NaN
# std                          NaN                                    NaN
# min                          NaN                                    NaN
# 25%                          NaN                                    NaN
# 50%                          NaN                                    NaN
# 75%                          NaN                                    NaN
# max                          NaN                                    NaN
#
#         ISO numeric country/territory code Region         Year  \
# count                          4954.000000   4954  4954.000000
# unique                                 NaN      6          NaN
# top                                    NaN    EUR          NaN
# freq                                   NaN   1240          NaN
# mean                            432.061365    NaN  2001.512111
# std                             255.471742    NaN     6.925722
# min                               4.000000    NaN  1990.000000
# 25%                             212.000000    NaN  1995.000000
# 50%                             428.000000    NaN  2002.000000
# 75%                             646.000000    NaN  2008.000000
# max                             894.000000    NaN  2013.000000
#
#         Estimated total population number  \
# count                        4.954000e+03
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                         3.013292e+07
# std                          1.202176e+08
# min                          1.426000e+03
# 25%                          8.206685e+05
# 50%                          5.416784e+06
# 75%                          1.855006e+07
# max                          1.385567e+09
#
#         Estimated prevalence of TB (all forms) per 100 000 population  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           200.527614
# std                                            261.080015
# min                                              1.200000
# 25%                                             26.000000
# 50%                                             94.000000
# 75%                                            285.000000
# max                                           1762.000000
#
#         Estimated prevalence of TB (all forms)  \
# count                             4.954000e+03
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                              6.877303e+04
# std                               3.301170e+05
# min                               2.300000e+00
# 25%                               4.600000e+02
# 50%                               5.300000e+03
# 75%                               2.800000e+04
# max                               4.600000e+06
#
#        Method to derive prevalence estimates  \
# count                                   4954
# unique                                     5
# top                                predicted
# freq                                    4594
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#         Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            20.753599
# std                                             33.265669
# min                                              0.000000
# 25%                                              1.500000
# 50%                                              5.700000
# 75%                                             26.000000
# max                                            278.000000
#
#         Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            13.740692
# std                                             22.576935
# min                                              0.000000
# 25%                                              0.992500
# 50%                                              4.000000
# 75%                                             17.000000
# max                                            202.000000
#
#         Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            28.200416
# std                                             45.097515
# min                                              0.000000
# 25%                                              1.800000
# 50%                                              8.500000
# 75%                                             35.000000
# max                                            354.000000
#
#         Estimated number of deaths from TB (all forms, excluding HIV)  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          7093.977235
# std                                          31036.081755
# min                                              0.000000
# 25%                                             22.000000
# 50%                                            320.000000
# 75%                                           2400.000000
# max                                         420000.000000
#
#         Estimated number of deaths from TB (all forms, excluding HIV), low bound  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          4874.570941
# std                                          21044.702957
# min                                              0.000000
# 25%                                             15.000000
# 50%                                            200.000000
# 75%                                           1600.000000
# max                                         290000.000000
#
#         Estimated number of deaths from TB (all forms, excluding HIV), high bound  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          9406.113333
# std                                          42588.586413
# min                                              0.000000
# 25%                                             27.000000
# 50%                                            390.000000
# 75%                                           3000.000000
# max                                         590000.000000
#
#         Estimated mortality of TB cases who are HIV-positive, per 100 000 population  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            12.225382
# std                                             46.139222
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.070000
# 75%                                              2.400000
# max                                            481.000000
#
#         Estimated number of deaths from TB in people who are HIV-positive  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          1859.002586
# std                                           8040.279830
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              8.000000
# 75%                                            290.000000
# max                                          96000.000000
#
#        Method to derive mortality estimates  \
# count                                  4954
# unique                                    3
# top                                      VR
# freq                                   2129
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#         Estimated incidence (all forms) per 100 000 population  \
# count                                         4954.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           139.055733
# std                                            191.652008
# min                                              0.000000
# 25%                                             20.000000
# 50%                                             65.000000
# 75%                                            189.000000
# max                                           1662.000000
#
#         Estimated number of incident cases (all forms)
# count                                     4.954000e+03
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                      4.360200e+04
# std                                       1.895082e+05
# min                                       0.000000e+00
# 25%                                       3.400000e+02
# 50%                                       3.800000e+03
# 75%                                       1.900000e+04
# max                                       2.400000e+06

# %%
df_excl_outliers.columns
# Out:
# Index(['Country or territory name', 'ISO 3-character country/territory code',
#        'ISO numeric country/territory code', 'Region', 'Year',
#        'Estimated total population number',
#        'Estimated prevalence of TB (all forms) per 100 000 population',
#        'Estimated prevalence of TB (all forms)',
#        'Method to derive prevalence estimates',
#        'Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound',
#        'Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV)',
#        'Estimated number of deaths from TB (all forms, excluding HIV), low bound',
#        'Estimated number of deaths from TB (all forms, excluding HIV), high bound',
#        'Estimated mortality of TB cases who are HIV-positive, per 100 000 population',
#        'Estimated number of deaths from TB in people who are HIV-positive',
#        'Method to derive mortality estimates',
#        'Estimated incidence (all forms) per 100 000 population',
#        'Estimated number of incident cases (all forms)'],
#       dtype='object')

# %%
df_excl_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4954 entries, 0 to 5119
# Data columns (total 20 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Country or territory name                                                                       4954 non-null   object
#  1   ISO 3-character country/territory code                                                          4954 non-null   object
#  2   ISO numeric country/territory code                                                              4954 non-null   int64
#  3   Region                                                                                          4954 non-null   object
#  4   Year                                                                                            4954 non-null   int64
#  5   Estimated total population number                                                               4954 non-null   int64
#  6   Estimated prevalence of TB (all forms) per 100 000 population                                   4954 non-null   float64
#  7   Estimated prevalence of TB (all forms)                                                          4954 non-null   float64
#  8   Method to derive prevalence estimates                                                           4954 non-null   object
#  9   Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population               4954 non-null   float64
#  10  Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound   4954 non-null   float64
#  11  Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound  4954 non-null   float64
#  12  Estimated number of deaths from TB (all forms, excluding HIV)                                   4954 non-null   float64
#  13  Estimated number of deaths from TB (all forms, excluding HIV), low bound                        4954 non-null   float64
#  14  Estimated number of deaths from TB (all forms, excluding HIV), high bound                       4954 non-null   float64
#  15  Estimated mortality of TB cases who are HIV-positive, per 100 000 population                    4954 non-null   float64
#  16  Estimated number of deaths from TB in people who are HIV-positive                               4954 non-null   float64
#  17  Method to derive mortality estimates                                                            4954 non-null   object
#  18  Estimated incidence (all forms) per 100 000 population                                          4954 non-null   float64
#  19  Estimated number of incident cases (all forms)                                                  4954 non-null   float64
# dtypes: float64(12), int64(3), object(5)
# memory usage: 812.8+ KB

# %%
df_numbers = df_excl_outliers.drop(columns=['Country or territory name', 'ISO 3-character country/territory code',
                                            'Region', 'Method to derive prevalence estimates', 'Method to derive mortality estimates'], axis=1)
df_numbers.shape
# Out:
# (4954, 15)

# %%
df_numbers
# Out:
#       ISO numeric country/territory code  Year  \
# 0                                      4  1990
# 1                                      4  1991
# 2                                      4  1992
# 3                                      4  1993
# 4                                      4  1994
# ...                                  ...   ...
# 5115                                 716  2009
# 5116                                 716  2010
# 5117                                 716  2011
# 5118                                 716  2012
# 5119                                 716  2013
#
#       Estimated total population number  \
# 0                              11731193
# 1                              12612043
# 2                              13811876
# 3                              15175325
# 4                              16485018
# ...                                 ...
# 5115                           12888918
# 5116                           13076978
# 5117                           13358738
# 5118                           13724317
# 5119                           14149648
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                                 306.0
# 1                                                 343.0
# 2                                                 371.0
# 3                                                 392.0
# 4                                                 410.0
# ...                                                 ...
# 5115                                              449.0
# 5116                                              415.0
# 5117                                              417.0
# 5118                                              425.0
# 5119                                              409.0
#
#       Estimated prevalence of TB (all forms)  \
# 0                                    36000.0
# 1                                    43000.0
# 2                                    51000.0
# 3                                    59000.0
# 4                                    68000.0
# ...                                      ...
# 5115                                 58000.0
# 5116                                 54000.0
# 5117                                 56000.0
# 5118                                 58000.0
# 5119                                 58000.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# 0                                                  37.0
# 1                                                  46.0
# 2                                                  54.0
# 3                                                  60.0
# 4                                                  65.0
# ...                                                 ...
# 5115                                               39.0
# 5116                                               36.0
# 5117                                               38.0
# 5118                                               41.0
# 5119                                               40.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound  \
# 0                                                  24.0
# 1                                                  29.0
# 2                                                  34.0
# 3                                                  38.0
# 4                                                  41.0
# ...                                                 ...
# 5115                                               27.0
# 5116                                               25.0
# 5117                                               26.0
# 5118                                               27.0
# 5119                                               25.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, high bound  \
# 0                                                  54.0
# 1                                                  61.0
# 2                                                  68.0
# 3                                                  73.0
# 4                                                  79.0
# ...                                                 ...
# 5115                                               52.0
# 5116                                               48.0
# 5117                                               51.0
# 5118                                               55.0
# 5119                                               52.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV)  \
# 0                                                4300.0
# 1                                                5800.0
# 2                                                7400.0
# 3                                                9100.0
# 4                                               11000.0
# ...                                                 ...
# 5115                                             5000.0
# 5116                                             4700.0
# 5117                                             5100.0
# 5118                                             5600.0
# 5119                                             5700.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV), low bound  \
# 0                                                2800.0
# 1                                                3700.0
# 2                                                4700.0
# 3                                                5800.0
# 4                                                6800.0
# ...                                                 ...
# 5115                                             3500.0
# 5116                                             3300.0
# 5117                                             3500.0
# 5118                                             3700.0
# 5119                                             3600.0
#
#       Estimated number of deaths from TB (all forms, excluding HIV), high bound  \
# 0                                                6400.0
# 1                                                7700.0
# 2                                                9400.0
# 3                                               11000.0
# 4                                               13000.0
# ...                                                 ...
# 5115                                             6700.0
# 5116                                             6300.0
# 5117                                             6800.0
# 5118                                             7500.0
# 5119                                             7400.0
#
#       Estimated mortality of TB cases who are HIV-positive, per 100 000 population  \
# 0                                                  0.04
# 1                                                  0.06
# 2                                                  0.08
# 3                                                  0.11
# 4                                                  0.13
# ...                                                 ...
# 5115                                             206.00
# 5116                                             196.00
# 5117                                             176.00
# 5118                                             160.00
# 5119                                             153.00
#
#       Estimated number of deaths from TB in people who are HIV-positive  \
# 0                                                   5.0
# 1                                                   8.0
# 2                                                  11.0
# 3                                                  17.0
# 4                                                  22.0
# ...                                                 ...
# 5115                                            27000.0
# 5116                                            26000.0
# 5117                                            24000.0
# 5118                                            22000.0
# 5119                                            22000.0
#
#       Estimated incidence (all forms) per 100 000 population  \
# 0                                                 189.0
# 1                                                 191.0
# 2                                                 191.0
# 3                                                 189.0
# 4                                                 188.0
# ...                                                 ...
# 5115                                              673.0
# 5116                                              635.0
# 5117                                              602.0
# 5118                                              575.0
# 5119                                              552.0
#
#       Estimated number of incident cases (all forms)
# 0                                            22000.0
# 1                                            24000.0
# 2                                            26000.0
# 3                                            29000.0
# 4                                            31000.0
# ...                                              ...
# 5115                                         87000.0
# 5116                                         83000.0
# 5117                                         80000.0
# 5118                                         79000.0
# 5119                                         78000.0
#
# [4954 rows x 15 columns]

# %%
grouped_data = dataset_df.groupby('Estimated prevalence of TB (all forms)')['Year'].apply(list)
hiv_grouped_data = dataset_df.groupby('Estimated prevalence of TB (all forms)')['Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population'].apply(list)
hiv_grouped_data
# Out:
# Estimated prevalence of TB (all forms)
# 0.00                            [21.0]
# 0.07                            [21.0]
# 0.33                            [21.0]
# 0.41                             [3.9]
# 0.44                        [4.2, 4.1]
#                         ...
# 4200000.00                      [38.0]
# 4300000.00                [38.0, 37.0]
# 4400000.00          [38.0, 38.0, 38.0]
# 4500000.00          [38.0, 39.0, 39.0]
# 4600000.00    [39.0, 39.0, 39.0, 39.0]
# Name: Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population, Length: 513, dtype: object

# %%
import scipy.stats as stats
f_statistic, p_value=stats.f_oneway(*grouped_data)

print('this is our f-stat: ', f_statistic)
print('this is our p_value: ', p_value)
# Out:
# this is our f-stat:  1.3099239386473813
# this is our p_value:  1.9981573964785423e-05

# %%
hiv_f_statistic, hiv_p_value=stats.f_oneway(*hiv_grouped_data)

print('this is our f-stat: ', hiv_f_statistic)
print('this is our p_value: ', hiv_p_value)
# Out:
# this is our f-stat:  2.401360619569274
# this is our p_value:  6.547577373635143e-46

# %%
sns.relplot(x="Estimated prevalence of TB (all forms)", y="Estimated total population number", hue="Country or territory name", size="Estimated prevalence of TB (all forms) per 100 000 population", 
           sizes=(40, 400), alpha=.5, palette='muted', height=6, data=df_excl_outliers)

# %%
sns.barplot(x="Year", y="Estimated prevalence of TB (all forms)", data=df_excl_outliers)
plt.title("Prevalenve of TB (all forms) per year")
plt.show()

# %%
sns.set_theme(style="ticks")

# Plot the responses for different events and regions
sns.lineplot(x="Estimated prevalence of TB (all forms)", y="Year",
             hue="Year", style="Year",
             data=df_excl_outliers)
# Out:
# <Axes: xlabel='Estimated prevalence of TB (all forms)', ylabel='Year'>

# %%
dataset_df.to_csv('final_dataset.csv', index=False)

# %%
#This dataset is an observational study of all the Tuberculosis cases in each country from 1990 to 2013, effects of HIV in a Turberculosis case, and the mortality rates.
#To clean the dataset I removed the duplicate rows in the dataset, if any.
#I then removed all columns in the dataset that had null values.
#I then went and made sure the data was consistent and all columns had valid data types present.
#I then took out any outliers in the data before starting data visualization.
#I created box and whisker plots and histograms of the data that excluded the outliers in the dataset.
#I grouped the data of the year and Estimated prevalence of TB to see if there was any similarities.
#I created seaborne graphs to better help visualize the dataset and while doing so I saw that the highest cases of TB were found in the 90's. The cases of TB kept rising until an all time high in 1997 and slowing fell to about half those cases in 2012-2013.
#To summarize my findings, the rise of TB was during the 1990's with an all time high in 1997. After the cases peaked they remained around the same for 3 years then decreased about an 1/8 of the cases. Following the year 2000 the TB cases continued to both decrease and jump a little until 2013 where the TB cases had halfed since 1997.
